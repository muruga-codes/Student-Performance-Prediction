# %% [markdown]
# 📘 Day 5 – Model Optimization & Final Insights

# %% [markdown]
# 🎯 Objective:
# Optimize the model and finalize the best-performing algorithm for predicting G3.

# %% [markdown]
# 📊 Steps Performed:
# 1️⃣ Applied Cross-Validation
# Used K-Fold Cross Validation
#
# Checked model stability across multiple splits
#
# Ensured consistent performance
#
# Purpose:
# Avoid depending on a single train-test split.

# %% [markdown]
# 2️⃣ Hyperparameter Tuning
# Tuned Decision Tree parameters:
#
# max_depth
#
# min_samples_split
#
# Compared performance before & after tuning
#
# Goal:
# Reduce overfitting and improve generalization.

# %% [markdown]
# 3️⃣ Model Comparison
# Compared:
#
# Linear Regression
#
# Decision Tree Regressor
#
# Random Forest Regressor
#
# Observation:
#
# Linear Regression performed consistently well
#
# Random Forest handled non-linear patterns better
#
# Decision Tree needed tuning to avoid overfitting

# %% [markdown]
# 4️⃣ Final Model Selection
# Selected model based on:
# ✔ Higher R² score
# ✔ Lower MAE
# ✔ Better generalization
# ✔ Stability in cross-validation

# %% [markdown]
# 🔎 Final Insight:
# Previous grades (G1 & G2) are the strongest predictors of final grade (G3).
# Behavioral and study-related features also influence performance but with lower impact.
