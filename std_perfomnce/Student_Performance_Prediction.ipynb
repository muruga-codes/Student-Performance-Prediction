# %% [markdown]
# 🚀Student-Performance-Prediction project

# %% [markdown]
# 🚀 DAY 1 – Project Foundation & Planning
#
# Today is NOT about coding heavily.
# Today is about thinking like a real ML engineer 🧠

# %% [markdown]
# 🎯 1️⃣ Understand the Problem Clearly
# 📌 Problem Statement
#
# Predict a student's final grade (G3) using:
#
# Academic data
#
# Demographic data
#
# Behavioral data
#
# 📌 Why this project matters?
#
# ✔ Helps teachers identify weak students early
# ✔ Helps schools improve performance
# ✔ Helps in data-driven academic decisions

# %% [markdown]
# 📊 2️⃣ Understand the Type of ML Problem
#
# This is:
#
# ✅ Supervised Learning
#
# ✅ Regression Problem (Predicting numerical grade)
#
# Later you can also convert it into:
#
# ✅ Classification (Pass/Fail)

# %% [markdown]
# 📥 3️⃣ Download the Dataset
#
# Dataset: Student Performance Dataset
#
# Source: UCI Machine Learning Repository
#
# Download:
# 👉 https://archive.ics.uci.edu/ml/datasets/student+performance
#
# Download:
#
# student-mat.csv (Math students)

# %% [markdown]
# 📁 4️⃣ Create Project Folder Structure
#
# Create this in your system:
#
# Student-Performance-Prediction/
# │
# ├── data/
# ├── notebooks/
# ├── model/
# ├── app.py
# ├── requirements.txt
# ├── README.md
#
# Put the CSV file inside the data folder.

# %% [markdown]
# 🧠 5️⃣ Understand the Dataset Columns
# Feature	Meaning
# studytime	Weekly study time
# failures	Past class failures
# absences	Number of absences
# G1	First period grade
# G2	Second period grade
# G3	Final grade (Target)

# %% [markdown]
# 🔎 6️⃣ Open Dataset in Jupyter Notebook
#
# Create file inside notebooks:
#
# analysis.ipynb

# %%
import pandas as pd

df = pd.read_csv("../data/student-mat.csv", sep=";")

print(df.shape)
print(df.head())
print(df.info())
# Out:
# (395, 33)
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# ...

# %% [markdown]
# 🧠 7️⃣ Analyze Basic Questions (Very Important)
# How many students are there?
#
# How many features?
#
# Are there missing values?
#
# What is average final grade?
#
# What is grade distribution?

# %%
print(df.describe())
print(df.isnull().sum())
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %% [markdown]
# 📊 8️⃣ Visualize Target Variable

# %%
import matplotlib.pyplot as plt

plt.hist(df["G3"])
plt.title("Final Grade Distribution")
plt.xlabel("Grade")
plt.ylabel("Number of Students")
plt.show()

# %% [markdown]
# 🧾 9️⃣ Write Notes
#
# Create a small note file:
#
# project_notes.txt
#
# Write:
#
# Dataset size:
#
# Target variable:
#
# Initial observations:
#
# Any imbalance?
