# %% [markdown]
# 📅 Day 11 Tasks

# %% [markdown]
# 1️⃣ Evaluate the Machine Learning Model

# %% [markdown]
# Metrics you should calculate:
#
# MAE (Mean Absolute Error)
#
# MSE (Mean Squared Error)
#
# R² Score

# %%
import pickle
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Load dataset
df = pd.read_csv("../data/student-mat.csv", sep=";")

X = df[["studytime", "absences", "G1", "G2"]]
y = df["G3"]

# Load trained model
with open("model/student_model.pkl", "rb") as f:
    model = pickle.load(f)

# Predictions
predictions = model.predict(X)

# Metrics
mae = mean_absolute_error(y, predictions)
mse = mean_squared_error(y, predictions)
r2 = r2_score(y, predictions)

print("Model Evaluation Results")
print("MAE:", mae)
print("MSE:", mse)
print("R2 Score:", r2)
# Out:
# Model Evaluation Results
# MAE: 0.6133827004219409
# MSE: 1.3870909364642436
# R2 Score: 0.9337476471472193

# %% [markdown]
# 📊 2️⃣ Add Data Visualization

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("../data/student-mat.csv", sep=";")

plt.figure(figsize=(8,5))
sns.scatterplot(x="G1", y="G3", data=df)
plt.title("G1 vs Final Grade")
plt.show()

# %% [markdown]
# You can create charts for:
#
# Studytime vs Final Grade
#
# Absences vs Final Grade
#
# G1 vs G3
#
# G2 vs G3
